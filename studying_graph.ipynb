# %%
time_studying <- c(2, 3, 5, 7, 8, 10, 11, 12, 14, 15)  
time_outside <- c(8, 7, 5, 5, 4, 3, 3, 2, 1, 1)       

plot(time_studying, time_outside,
     main = "Scatter Plot of Time Spent Studying vs Time Spent Outside",
     xlab = "Time Spent Studying (hours)",
     ylab = "Time Spent Outside (hours)",
     col = "blue",
     pch = 19)
# Out:
# Plot with title “Scatter Plot of Time Spent Studying vs Time Spent Outside”
